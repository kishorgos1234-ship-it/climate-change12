# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorgos1234-ship-it/climate-change12/blob/main/Copy_of_climate_change(2022333515).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/shohinurpervezshohan/bangladesh-climate-change-simulation-dataset")
# Out:
# Skipping, found downloaded files in "./bangladesh-climate-change-simulation-dataset" (use force=True to force download)

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/bangladesh-climate-change-simulation-dataset/Bangladesh_Environmental_Climate_Change_Impact.csv")

# %%
data.head()
# Out:
#    Year   District  Avg_Temperature_C  Annual_Rainfall_mm  AQI  \
# 0  2025   Satkhira              27.06              4044.6  257
# 1  2018    Tangail              25.86              1659.1  222
# 2  2013  Sunamganj              25.20              3618.1   56
# 3  2005  Sirajganj              27.85              4031.3  171
# 4  2013   Barishal              29.94              3844.4  259
#
#    Forest_Cover_Percent  River_Water_Level_m  Cyclone_Count  \
# 0                  9.36                 5.89              1
# 1                 29.12                 8.74              1
# 2                 24.01                 8.45              1
# 3                 25.68                 4.04              2
# 4                  8.13                 9.83              3
#
#    Flood_Impact_Score  Drought_Severity  Agricultural_Yield_ton_per_hectare  \
# 0                6.01              9.25                                5.21
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=data)
# Out:
# https://docs.google.com/spreadsheets/d/1TnNbY484HQO4rjv51yjKx-TrLTol_4JqVILKEEc1RrE/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1TnNbY484HQO4rjv51yjKx-TrLTol_4JqVILKEEc1RrE/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Year vs Avg_Temperature_C

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['Year']
  ys = series['Avg_Temperature_C']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('Year', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('Year')
_ = plt.ylabel('Avg_Temperature_C')
